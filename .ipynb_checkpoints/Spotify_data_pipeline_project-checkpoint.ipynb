# %%
# Install the Spotify library
# !pip install spotipy
# Out:
# ...
#    ---------------------------------------- 0.0/261.4 kB ? eta -:--:--
#    ---------------------------------------- 261.4/261.4 kB 8.1 MB/s eta 0:00:00
# ...

# %%
# Add important libraries
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
# This is used for authentication purposes 
# Here, I blanked the credentials for security purposes
client_credetials_manager = SpotifyClientCredentials(client_id = "8d24a30bd8ce4db1abefdee800b4092a", client_secret= "4e796e043d6b42aa99bacddac166f070")

# %%
# This is used for the authorization purpose
sp = spotipy.Spotify(client_credentials_manager = client_credetials_manager)

# %%
# Copy the URL from the Spotify website
playlist_link = 'https://open.spotify.com/playlist/1bvcVgSFFKobfJOWgsUrEe'

# %%
# Fetch the last id from the URL
playlist_URI = playlist_link.split("/")[-1]
playlist_URI
# Out:
# '1bvcVgSFFKobfJOWgsUrEe'

# %%
# make the object 'data' that fetches the raw data from the Spotify API
data = sp.playlist_tracks(playlist_URI)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/1bvcVgSFFKobfJOWgsUrEe/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-11-30T16:38:34Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31pvphkyuklsgq2iueofjjgur3iy'},
#     'href': 'https://api.spotify.com/v1/users/31pvphkyuklsgq2iueofjjgur3iy',
#     'id': '31pvphkyuklsgq2iueofjjgur3iy',
#     'type': 'user',
#     'uri': 'spotify:user:31pvphkyuklsgq2iueofjjgur3iy'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
# ...

# %%
# album, songs, artist
len(data['items'])
# Out:
# 88

# %%
# fetch the album 'ID' for one particular record
data['items'][0]['track']['album']['id']
# Out:
# '3IbKcMtNRze5t0ANwdp45H'

# %%
# fetch the album 'name' for one particular record
data['items'][0]['track']['album']['name']
# Out:
# 'Desi Kalakaar'

# %%
# fetch the album 'release_date' for one particular record
data['items'][0]['track']['album']['release_date']
# Out:
# '2014-09-26'

# %%
# fetch the album 'total_track' for one particlar record
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
# fetch the album 'external_urls' for one particlar record
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/3IbKcMtNRze5t0ANwdp45H'

# %%
# create album list from the raw data
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_dic = {'album_id' : album_id, 'album_name' : album_name, 'album_release_date' : album_release_date, 'album_total_tracks' : album_total_tracks, 'album_url' : album_url}
    album_list.append(album_dic)

# %%
# print the album list
album_list
# Out:
# [{'album_id': '3IbKcMtNRze5t0ANwdp45H',
#   'album_name': 'Desi Kalakaar',
#   'album_release_date': '2014-09-26',
#   'album_total_tracks': 8,
#   'album_url': 'https://open.spotify.com/album/3IbKcMtNRze5t0ANwdp45H'},
#  {'album_id': '0KvWbswDD0ksvFayBl6gUz',
#   'album_name': 'Teri Baaton Mein Aisa Uljha Jiya',
#   'album_release_date': '2024-02-05',
#   'album_total_tracks': 4,
#   'album_url': 'https://open.spotify.com/album/0KvWbswDD0ksvFayBl6gUz'},
#  {'album_id': '1GYaUPrWVZzuNldVZRhGJn',
#   'album_name': 'Soulful Songs Of Rahat Fateh Ali Khan',
#   'album_release_date': '2024-04-25',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/1GYaUPrWVZzuNldVZRhGJn'},
#  {'album_id': '1ijVIXFdGfbL9eIR1Xz5we',
#   'album_name': 'Best of 2019 Punjabi Love Songs',
#   'album_release_date': '2019-12-20',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/1ijVIXFdGfbL9eIR1Xz5we'},
#  {'album_id': '49g8Aqji0Lw9rTeI5Av4Va',
# ...

# %%
# fetch artist records
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7uIbLdzzSEqnX0Pkrb56cR'},
#   'href': 'https://api.spotify.com/v1/artists/7uIbLdzzSEqnX0Pkrb56cR',
#   'id': '7uIbLdzzSEqnX0Pkrb56cR',
#   'name': 'Yo Yo Honey Singh',
#   'type': 'artist',
#   'uri': 'spotify:artist:7uIbLdzzSEqnX0Pkrb56cR'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2024-11-30T16:38:34Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31pvphkyuklsgq2iueofjjgur3iy'},
#   'href': 'https://api.spotify.com/v1/users/31pvphkyuklsgq2iueofjjgur3iy',
#   'id': '31pvphkyuklsgq2iueofjjgur3iy',
#   'type': 'user',
#   'uri': 'spotify:user:31pvphkyuklsgq2iueofjjgur3iy'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
# ...

# %%
# create the artist_list that stores all artist data
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dic = {'artist_id': artist['id'], 'artist_name' : artist['name'], 'external_url' : artist['href']}
                artist_list.append(artist_dic)

# %%
# print artist list
artist_list
# Out:
# [{'artist_id': '7uIbLdzzSEqnX0Pkrb56cR',
#   'artist_name': 'Yo Yo Honey Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/7uIbLdzzSEqnX0Pkrb56cR'},
#  {'artist_id': '5PVSEFUT4Inqu3yEq56Ku9',
#   'artist_name': 'Raghav',
#   'external_url': 'https://api.spotify.com/v1/artists/5PVSEFUT4Inqu3yEq56Ku9'},
#  {'artist_id': '4f7KfxeHq9BiylGmyXepGt',
#   'artist_name': 'Tanishk Bagchi',
#   'external_url': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt'},
#  {'artist_id': '1sVmXkzX2ukc6QvasrDBES',
#   'artist_name': 'Asees Kaur',
#   'external_url': 'https://api.spotify.com/v1/artists/1sVmXkzX2ukc6QvasrDBES'},
#  {'artist_id': '3tGyiAF7Oo7m9G8sdJZ2XI',
#   'artist_name': 'Nina Mathur',
#   'external_url': 'https://api.spotify.com/v1/artists/3tGyiAF7Oo7m9G8sdJZ2XI'},
#  {'artist_id': '3OLGltG8UPIea8sA4w0yg0',
#   'artist_name': 'Rahat Fateh Ali Khan',
#   'external_url': 'https://api.spotify.com/v1/artists/3OLGltG8UPIea8sA4w0yg0'},
# ...

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
# ...

# %%
# create the song list
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularly = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {
        'song_id' : song_id, 'song_name' : song_name, 'song_duration' : song_duration, 'song_url' : song_url, 'song_popularly' : song_popularly, 
        'song_added' : song_added, 'album_id' : album_id, 'artist_id' : artist_id
    }
    song_list.append(song_element)

# %%
# print song list
song_list
# Out:
# [{'song_id': '1QZRCi2Z1DQQaR6bGAzhtN',
#   'song_name': 'Love Dose',
#   'song_duration': 224444,
#   'song_url': 'https://open.spotify.com/track/1QZRCi2Z1DQQaR6bGAzhtN',
#   'song_popularly': 72,
#   'song_added': '2024-11-30T16:38:34Z',
#   'album_id': '3IbKcMtNRze5t0ANwdp45H',
#   'artist_id': '7uIbLdzzSEqnX0Pkrb56cR'},
#  {'song_id': '2qBBAuIg8FUBYiJ3QRrVsP',
#   'song_name': 'Teri Baaton Mein Aisa Uljha Jiya Title Song',
#   'song_duration': 153083,
#   'song_url': 'https://open.spotify.com/track/2qBBAuIg8FUBYiJ3QRrVsP',
#   'song_popularly': 65,
#   'song_added': '2024-11-30T16:38:39Z',
#   'album_id': '0KvWbswDD0ksvFayBl6gUz',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '0oRgjkJQJAtx0oBxnUPFxv',
#   'song_name': 'Tere Mast Mast Do Nain',
#   'song_duration': 357982,
#   'song_url': 'https://open.spotify.com/track/0oRgjkJQJAtx0oBxnUPFxv',
#   'song_popularly': 51,
#   'song_added': '2024-11-30T16:38:43Z',
#   'album_id': '1GYaUPrWVZzuNldVZRhGJn',
# ...

# %%
# convert album list into dataframe
album_df = pd.DataFrame.from_dict(album_list)

# %%
# convert artist list into dataframe
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
# convert song list into dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                    song_id                                        song_name  \
# 0   1QZRCi2Z1DQQaR6bGAzhtN                                        Love Dose
# 1   2qBBAuIg8FUBYiJ3QRrVsP      Teri Baaton Mein Aisa Uljha Jiya Title Song
# 2   0oRgjkJQJAtx0oBxnUPFxv                           Tere Mast Mast Do Nain
# 3   3OIZtOOYUeu1955WSAaIDZ                                         Udaarian
# 4   15C2MmLAPMwo2KtNWRh6vg  Bom Diggy Diggy (From "Sonu Ke Titu Ki Sweety")
# ..                     ...                                              ...
# 83  1AeWlwJlKN2i4psCp2vaJp     JAB HAM BADE HO JAYENGE - DOREMON THEME SONG
# 84  1r4oikmMdZZiGHkPA4hSoe                                 Character Dheela
# 85  6CoEiaHC5OLIJGG9R0A0jp                                Such Keh Raha Hai
# 86  5Ggb9pKiKcr5vNV9v1e1vs          Tumhare Hi Rahenge Hum (From "Stree 2")
# 87  4brSaQIT3bnnE41D042fgL                                   Tu Hai Ki Nahi
#
# ...

# %%
# drop duplicates from the album df (cleaning process)
album_df = album_df.drop_duplicates(subset = ['album_id'])

# %%
# drop duplicates from the artist df (cleaning process)
artist_df = artist_df.drop_duplicates(subset = ['artist_id'])

# %%
# drop duplicates from the songs df (cleaning process)
song_df = song_df.drop_duplicates(subset = ['song_id'])

# %%
# convert 'album_release_date' into the DateTime object
album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'])

# %%
# convert 'song_added' into the DateTime object
song_df['song_added'] = pd.to_datetime(song_df['song_added'])
